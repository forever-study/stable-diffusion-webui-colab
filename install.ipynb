# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/$sdw-colab/blob/drive/install.ipynb)

# %%
# %cd /content
from google.colab import drive
drive.mount('/content/drive')
import sys
import os
import base64

w = base64.b64decode(("d2VidWk=").encode('ascii')).decode('ascii')
sdw = base64.b64decode(("c3RhYmxlLWRpZmZ1c2lvbi13ZWJ1aQ==").encode('ascii')).decode('ascii')

# %env PYTHONDONTWRITEBYTECODE=1

# !apt-get -y install -qq aria2 libcairo2-dev pkg-config python3-dev

# !git clone -b v2.2 https://github.com/camenduru/$sdw /content/drive/MyDrive/$sdw-colab/$sdw
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw checkout -f v2.2
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw pull origin v2.2
# !git clone https://huggingface.co/embed/negative /content/drive/MyDrive/$sdw-colab/$sdw/embeddings/negative
# !git clone https://huggingface.co/embed/lora /content/drive/MyDrive/$sdw-colab/$sdw/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/models/ESRGAN -o 4x-UltraSharp.pth
# !wget https://raw.githubusercontent.com/camenduru/$sdw-scripts/main/run_n_times.py -O /content/drive/MyDrive/$sdw-colab/$sdw/scripts/run_n_times.py
# !rm -rf /content/drive/MyDrive/$sdw-colab/$sdw/extensions/deforum-for-automatic1111-$w
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-$w /content/drive/MyDrive/$sdw-colab/$sdw/extensions/deforum-for-automatic1111-$w
# !rm -rf /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-images-browser
# !git clone https://github.com/camenduru/$sdw-images-browser /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-images-browser
# !git clone https://github.com/camenduru/$sdw-huggingface /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-huggingface
# !rm -rf /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-civitai-browser
# !git clone https://github.com/camenduru/sd-civitai-browser /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-$w-additional-networks /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-additional-networks
# !rm -rf /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet
# !git clone https://github.com/Mikubill/sd-$w-controlnet /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet
# !rm -rf /content/drive/MyDrive/$sdw-colab/$sdw/extensions/openpose-editor
# !git clone https://github.com/fkunn1326/openpose-editor /content/drive/MyDrive/$sdw-colab/$sdw/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-$w-depth-lib /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-depth-lib
# !git clone https://github.com/hnmr293/posex /content/drive/MyDrive/$sdw-colab/$sdw/extensions/posex
# !git clone https://github.com/nonnonstop/sd-$w-3d-open-pose-editor /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-3d-open-pose-editor
# !git clone https://github.com/camenduru/sd-$w-tunnels /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-tunnels
# !git clone https://github.com/etherealxx/batchlinks-$w /content/drive/MyDrive/$sdw-colab/$sdw/extensions/batchlinks-$w
# !rm -rf /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-catppuccin
# !git clone https://github.com/camenduru/$sdw-catppuccin /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-catppuccin
# !git clone https://github.com/AUTOMATIC1111/$sdw-rembg /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-rembg
# !git clone https://github.com/ashen-sensored/$sdw-two-shot /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-two-shot
# !git clone https://github.com/thomasasfk/sd-$w-aspect-ratio-helper /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-aspect-ratio-helper
# %cd /content/drive/MyDrive/$sdw-colab/$sdw

# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/deforum-for-automatic1111-$w reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/deforum-for-automatic1111-$w pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-images-browser reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-images-browser pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-huggingface reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-huggingface pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-civitai-browser reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-civitai-browser pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-additional-networks reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-additional-networks pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/openpose-editor reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/openpose-editor pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-depth-lib reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-depth-lib pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/posex reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/posex pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-tunnels reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-tunnels pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/batchlinks-$w reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/batchlinks-$w pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-catppuccin reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-catppuccin pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-rembg reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-rembg pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-two-shot reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/$sdw-two-shot pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-3d-open-pose-editor reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-3d-open-pose-editor pull
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-aspect-ratio-helper reset --hard
# !git -C /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-aspect-ratio-helper pull

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_ip2p_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_shuffle_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_canny_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1p_sd15_depth_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_inpaint_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_lineart_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_mlsd_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_normalbae_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_openpose_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_scribble_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_seg_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_softedge_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1e_sd15_tile_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_ip2p_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11e_sd15_shuffle_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_canny_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1p_sd15_depth_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_inpaint_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_lineart_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_mlsd_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_normalbae_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_openpose_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_scribble_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_seg_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15_softedge_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o control_v11f1e_sd15_tile_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_canny_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_canny_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_depth_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_sketch_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -d /content/drive/MyDrive/$sdw-colab/$sdw/extensions/sd-$w-controlnet/models -o t2iadapter_zoedepth_sd15v1.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt -d /content/drive/MyDrive/$sdw-colab/$sdw/models/Stable-diffusion -o v1-5-pruned-emaonly.ckpt

# !sed -i -e 's/    start()/    #start()/g' /content/drive/MyDrive/$sdw-colab/$sdw/launch.py
# !sed -i -e 's/checkout {commithash}/checkout --force {commithash}/g' /content/drive/MyDrive/$sdw-colab/$sdw/launch.py

# %cd /content/drive/MyDrive/$sdw-colab/$sdw
# !python launch.py --skip-torch-cuda-test

print("Installed")
